# %% [markdown]
# <a href="https://colab.research.google.com/github/tharleshenriqye/LinearRegress-o/blob/main/LinearRegress%C3%A3oSimples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Este código demonstra um fluxo completo de machine learning para regressão linear simples, implementado em Python.

# %%
# Geração de Dados Sintéticos (Simulação Realista)

from sklearn.datasets import make_regression

import matplotlib.pyplot as plt

x, y = make_regression(n_samples=200, n_features=1, noise=30)

# %% [markdown]
# Cria 200 amostras com 1 feature/preditor
#
# Adiciona ruído de amplitude 30 para simular variações do mundo real
#
# x: Variável independente (característica)
#
# y: Variável dependente (alvo)

# %%
# Exploração e Visualização dos Dados

plt.scatter(x,y)

# %% [markdown]
# Gera um gráfico de dispersão para inspecionar:
#
# Relação linear entre as variáveis
#
# Distribuição dos pontos
#
# Impacto do ruído introduzido

# %%
# Modelagem Preditiva e Validação

from sklearn.linear_model import LinearRegression

modelo = LinearRegression()

modelo.fit(x, y)

modelo.predict(x)

plt.scatter(x,y)
plt.plot(x, modelo.predict(x), color="red", linewidth=3)
plt.show()

# %% [markdown]
# Implementa um modelo de regressão linear OLS (Mínimos Quadrados Ordinários)
#
# Treina o algoritmo com os dados gerados
#
# Valida visualmente o ajuste do modelo sobrepondo a reta de regressão aos dados

# %% [markdown]
# Conceitos-Chave Ilustrados
#
#
# Componente	Finalidade	Visualização
# Ponto de Dados	Observações individuais	Pontos azuis
# Reta de Regressão	Relação linear prevista	Linha vermelha
# Ruído	Variação não explicada	Dispersão dos pontos
# Saída Gráfica
# Primeiro plot: Nuvem de pontos bruta
#
# Segundo plot: Dados + Reta de regressão otimizada
# (Mostra como o modelo minimiza a distância total entre pontos e reta)
#
# Aplicações Práticas
# Este fluxo simula cenários reais como:
#
# Prever vendas baseado em investimento em marketing
#
# Estimar preços de imóveis por área construída
#
# Calcular consumo energético vs. produção industrial
#
# Interpretação Final: O código oferece uma base fundamental para entender como algoritmos de ML aprendem padrões de dados e fazem previsões quantitativas, validando visualmente a qualidade do ajuste do modelo.
